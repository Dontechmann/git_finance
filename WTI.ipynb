# %%
# %matplotlib inline
import os
import quandl

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('whitegrid')

# %%
oil = quandl.get('EIA/PET_RWTC_D', api_key='YOUR_QUANDL_API_KEY').squeeze() #YOUR_QUANDL_API_KEY에 입력

# %%
oil.plot(lw=2, title='WTI Crude Oil Price', figsize=(12, 4))
sns.despine()
plt.tight_layout();

# %%
- By SSH
